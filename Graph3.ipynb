# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data3.csv')

# %%
deathcovid19=df.groupby('AvgAge')['Covid'].sum()
allcause=df.groupby('AvgAge')['AllCause'].sum()
noncovid=df.groupby('AvgAge')['NonCovid'].sum()

# %%
plt.figure(figsize=(12, 6))

# %%
bar_width = 0.25
x = range(len(deathcovid19))

# %%
plt.bar(x, deathcovid19, bar_width, color='skyblue', label='Covid')
plt.bar([i + bar_width for i in x], allcause, bar_width, color='lightgreen', label='AllCause')
plt.bar([i + 2*bar_width for i in x], noncovid, bar_width, color='red', label='NonCovid')
plt.title('COVID-19 DEATH')
plt.xlabel('Age')
plt.ylabel('Deaths')
plt.xticks([i + 1.5*bar_width / 2 for i in x], deathcovid19.index)
plt.legend()
plt.show()
