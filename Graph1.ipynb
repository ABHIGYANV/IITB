# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('d2.csv')

# %%
x=df['Covid']
y=df['AgeGroup']

# %%
plt.bar(y, x)
plt.title('Country GDP')
plt.xlabel('Country')
plt.ylabel('GDP')
plt.show()
